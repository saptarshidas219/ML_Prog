# %%
from sklearn import tree
features = [
    [150, 0],  # Apple
    [170, 0],  # Apple
    [130, 1],  # Orange
    [120, 1],  # Orange
]
labels = ["apple", "apple", "orange", "orange"]

clf = tree.DecisionTreeClassifier()
cl = clf.fit(features, labels)
predict = clf.predict([[160, 0],[30,1],[150,1]])
print(predict)
# Out:
# ['apple' 'orange' 'orange']

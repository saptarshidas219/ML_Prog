# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('new_insurance_data.csv')

# %%
df.info()

# %%
df.sample(5)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1221  30.0    male  35.300       0.0    yes   40267.69557                26.0
# 33    18.0  female  38.170       0.0     no   45306.14266                 7.0
# 179   24.0  female  24.225       0.0     no   25672.59942                21.0
# 20    21.0    male  23.210       0.0     no   26792.20700                10.0
# 405   28.0    male  24.300       5.0     no   50103.89082                20.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1221     1037793.0          5.465370e+07                              2.0
# 33        727608.0          6.647150e+06                              0.0
# 179       800968.0          1.941782e+06                              1.0
# 20        720110.0          6.071186e+05                              0.0
# 405       851136.0          8.206516e+06                              1.0
#
#       Anual_Salary     region      charges
# ...

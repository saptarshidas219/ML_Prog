# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('new_insurance_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
df.sample(5)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 137   23.0    male  24.510       0.0     no   38358.04156                15.0
# 867   59.0    male  37.100       1.0     no   47949.48971                25.0
# 1195  24.0    male  31.065       0.0    yes   28416.34268                31.0
# 721   48.0    male  30.780       3.0     no   44983.52536                13.0
# 1296  55.0  female  35.200       0.0    yes   29807.41386                33.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 137       772972.0          2.346913e+06                              0.0
# 867       928859.0          3.298305e+06                              1.0
# 1195     1028637.0          4.709092e+07                              2.0
# 721       914033.0          6.386400e+06                              1.0
# 1296     1069003.0          8.949855e+07                              2.0
#
#       Anual_Salary     region      charges
# 137   5.426396e+07  northeast   2396.09590
# 867   2.213679e+08  southwest  12347.17200
# 1195  1.175548e+09  northeast  34254.05335
# 721   1.670645e+08  northeast  10141.13620
# 1296  2.058096e+09  southeast  44423.80300

# %%
df.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1329.000000  1335.000000  1333.000000   1324.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      14.034818     6.101690     1.201856  15617.288337
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.302500     0.000000  20768.860390
# 50%      39.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.687500     2.000000  45052.331957
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1332.000000  1.335000e+03          1.334000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.467723  9.188612e+04          2.669305e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.471995e+05          4.077633e+06
# 50%             15.000000  9.143000e+05          7.490337e+06
# 75%             20.000000  9.716840e+05          1.084082e+07
# max             40.000000  1.107872e+06          2.616317e+08
#
#        NUmber_of_past_hospitalizations  Anual_Salary       charges
# count                      1336.000000  1.332000e+03   1338.000000
# mean                          1.060629  3.696849e+08  13270.422265
# std                           0.533583  5.668843e+08  12110.011237
# min                           0.000000  2.747072e+06   1121.873900
# 25%                           1.000000  7.701932e+07   4740.287150
# 50%                           1.000000  1.419361e+08   9382.033000
# 75%                           1.000000  3.243499e+08  16639.912515
# max                           3.000000  4.117197e+09  63770.428010

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col]=df[col].fillna(df[col].mode()[0])

    else:
        df[col]=df[col].fillna(df[col].mean())

# %%
for col in df.columns:
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        sns.histplot(df[col], kde=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()

# %%
for col in df.columns:
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col}')
        plt.xlabel(col)
        plt.show()

# %%
q1_bmi = df['bmi'].quantile(0.25)
q3_bmi = df['bmi'].quantile(0.75)
iqr_bmi = q3_bmi - q1_bmi
lm_bmi = q1 -1.5*iqr
up_bmi = q3 + 1.5*iqr



q1_pc = df.past_consultations.quantile(0.25)
q3_pc = df.past_consultations.quantile(0.75)
iqr_pc = q3_pc - q1_pc
lm_pc = q1_pc - 1.5 * iqr_pc
up_pc = q3_pc + 1.5 * iqr_pc



q1_he = df.Hospital_expenditure.quantile(0.25)
q3_he = df.Hospital_expenditure.quantile(0.75)
iqr_he = q3_he - q1_he
lm_he = q1_he - 1.5 * iqr_he
up_he = q3_he + 1.5 * iqr_he




q1_sal = df.Anual_Salary.quantile(0.25)
q3_sal = df.Anual_Salary.quantile(0.75)
iqr_sal = q3_sal - q1_sal
lm_sal = q1_sal - 1.5 * iqr_sal
up_sal = q3_sal + 1.5 * iqr_sal


q1_charges = df.charges.quantile(0.25)
q3_charges = df.charges.quantile(0.75)
iqr_charges = q3_charges - q1_charges
lm_charges = q1_charges - 1.5 * iqr_charges
up_charges = q3_charges + 1.5 * iqr_charges

# %%
df_fill = df[(df['bmi'] >= lm_bmi) & (df['bmi'] <= up_bmi) &
             (df['past_consultations'] >= lm_pc) & (df['past_consultations'] <= up_pc) &
             (df['Hospital_expenditure'] >= lm_he) & (df['Hospital_expenditure'] <= up_he) &
             (df['Anual_Salary'] >= lm_sal) & (df['Anual_Salary'] <= up_sal) &
             (df['charges'] >= lm_charges) & (df['charges'] <= up_charges)]

# %%
for col in df_fill.columns:
    if df_fill[col].dtype == 'int64' or df_fill[col].dtype == 'float64':
        sns.boxplot(x=df_fill[col])
        plt.title(f'Boxplot of {col}')
        plt.xlabel(col)
        plt.show()

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1110 entries, 0 to 1140
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1101 non-null   float64
#  1   sex                              1110 non-null   object
#  2   bmi                              1110 non-null   float64
#  3   children                         1105 non-null   float64
#  4   smoker                           1110 non-null   object
#  5   Claim_Amount                     1099 non-null   float64
#  6   past_consultations               1110 non-null   float64
#  7   num_of_steps                     1107 non-null   float64
#  8   Hospital_expenditure             1110 non-null   float64
#  9   NUmber_of_past_hospitalizations  1109 non-null   float64
#  10  Anual_Salary                     1110 non-null   float64
#  11  region                           1110 non-null   object
#  12  charges                          1110 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 121.4+ KB

# %%
df.shape[0]-df_fill.shape[0]
# Out:
# 228
